# %% [markdown]
# ### MongoDB Implementation

# %%
#import necessary libraries

import json
import datetime
from pymongo import MongoClient
import pandas as pd

# %%
# MongoDB connection parameters

db_name = 'fleximart'
collection = 'products_catalog'
mongo_url = 'mongodb://localhost:27017'

# %%
# Load JSON data
with open('products_catalog.json', mode='r', encoding='utf-8') as f:
    data = json.load(f)

# %%
# Connect to MongoDB
client = MongoClient(mongo_url)
db = client[db_name]
col = db[collection]

# %% [markdown]
# #### Operation 1: Load Data

# %%
# Insert data into MongoDB
col.delete_many({})
rec = col.insert_many(data)
print(f"Inserted {len(rec.inserted_ids)} documents into {db_name}.{collection}")
# Out:
# Inserted 12 documents into fleximart.products_catalog

# %% [markdown]
# #### Operation 2: Basic Query
# - Find all products in "Electronics" category with price less than 50000
# - Return only: name, price, stock

# %%
#Basic Query
q2 = col.find(
    {"category": "Electronics", "price": {"$lt": 50000}},
    {"_id": 0, "name": 1, "price": 1, "stock": 1},
)

pd.DataFrame(list(q2))
# Out:
#                          name    price  stock
# 0  Sony WH-1000XM5 Headphones  29990.0    200
# 1     Dell 27-inch 4K Monitor  32999.0     60
# 2           OnePlus Nord CE 3  26999.0    180

# %% [markdown]
# #### Operation 3: Review Analysis (2 marks)
# - Find all products that have average rating >= 4.0
# - Use aggregation to calculate average from reviews array

# %%
#Aggregation Pipeline: Average Rating >= 4.0
pipeline3 = [
    {
        "$addFields": {
            "avg_rating": {
                "$avg": {"$ifNull": ["$reviews.rating", []]}  # safe if no reviews
            }
        }
    },
    {"$match": {"avg_rating": {"$gte": 4.0}}},
    {
        "$project": {
            "_id": 0,
            "product_id": 1,
            "name": 1,
            "category": 1,
            "avg_rating": {"$round": ["$avg_rating", 2]},
        }
    },
]


pd.DataFrame(list(col.aggregate(pipeline3)))
# Out:
#    product_id                        name     category  avg_rating
# 0     ELEC001    Samsung Galaxy S21 Ultra  Electronics        4.67
# 1     ELEC002   Apple MacBook Pro 14-inch  Electronics        5.00
# 2     ELEC003  Sony WH-1000XM5 Headphones  Electronics        4.67
# 3     ELEC004     Dell 27-inch 4K Monitor  Electronics        4.00
# 4     ELEC005           OnePlus Nord CE 3  Electronics        4.00
# 5     ELEC006     Samsung 55-inch QLED TV  Electronics        4.50
# 6     FASH001   Levi's 511 Slim Fit Jeans      Fashion        4.67
# 7     FASH002   Nike Air Max 270 Sneakers      Fashion        4.50
# 8     FASH003    Adidas Originals T-Shirt      Fashion        4.33
# 9     FASH004          Puma RS-X Sneakers      Fashion        4.50
# 10    FASH006  Reebok Training Trackpants      Fashion        4.50

# %% [markdown]
# #### Operation 4: Update Operation (2 marks)
# - Add a new review to product "ELEC001"
# - Review: {user: "U999", rating: 4, comment: "Good value", date: ISODate()}

# %%
new_review = {
    "user": "U999",
    "rating": 4,
    "comment": "Good value",
    "date": datetime.datetime.now(),  # stored as BSON Date (like ISODate)
}

# %%
res4 = col.update_one(
    {"product_id": "ELEC001"},
    {"$push": {"reviews": new_review}},
)
print({"matched": res4.matched_count, "modified": res4.modified_count})
# Out:
# {'matched': 1, 'modified': 1}

# %%
updated = col.find_one(
    {"product_id": "ELEC001"},
    {"_id": 0, "product_id": 1, "name": 1, "reviews": 1},
)

updated
# Out:
# {'product_id': 'ELEC001',
#  'name': 'Samsung Galaxy S21 Ultra',
#  'reviews': [{'user_id': 'U001',
#    'username': 'TechGuru',
#    'rating': 5,
#    'comment': 'Excellent phone with amazing camera quality!',
#    'date': '2024-01-15'},
#   {'user_id': 'U012',
#    'username': 'MobileUser',
#    'rating': 4,
#    'comment': 'Great performance but a bit pricey.',
#    'date': '2024-02-10'},
#   {'user_id': 'U023',
#    'username': 'PhotoEnthusiast',
#    'rating': 5,
#    'comment': "Best camera phone I've ever used!",
#    'date': '2024-03-05'},
#   {'user': 'U999',
#    'rating': 4,
#    'comment': 'Good value',
#    'date': datetime.datetime(2026, 1, 1, 11, 37, 27, 680000)}]}

# %% [markdown]
# #### Operation 5: Complex Aggregation
# - Calculate average price by category
# - Return: category, avg_price, product_count
# - Sort by avg_price descending

# %%
pipeline5 = [
    {
        "$group": {
            "_id": "$category",
            "avg_price": {"$avg": "$price"},
            "product_count": {"$sum": 1},
        }
    },
    {
        "$project": {
            "_id": 0,
            "category": "$_id",
            "avg_price": {"$round": ["$avg_price", 2]},
            "product_count": 1,
        }
    },
    {"$sort": {"avg_price": -1}},
]

pd.DataFrame(list(col.aggregate(pipeline5)))
# Out:
#    product_count     category  avg_price
# 0              6  Electronics   70830.83
# 1              6      Fashion    5215.00

# %%
pd.read_json('data/products_catalog.json')
# Out:
#    product_id                        name     category  subcategory   price  \
# 0     ELEC001    Samsung Galaxy S21 Ultra  Electronics  Smartphones   79999
# 1     ELEC002   Apple MacBook Pro 14-inch  Electronics      Laptops  189999
# 2     ELEC003  Sony WH-1000XM5 Headphones  Electronics        Audio   29990
# 3     ELEC004     Dell 27-inch 4K Monitor  Electronics     Monitors   32999
# 4     ELEC005           OnePlus Nord CE 3  Electronics  Smartphones   26999
# 5     ELEC006     Samsung 55-inch QLED TV  Electronics  Televisions   64999
# 6     FASH001   Levi's 511 Slim Fit Jeans      Fashion     Clothing    3499
# 7     FASH002   Nike Air Max 270 Sneakers      Fashion     Footwear   12995
# 8     FASH003    Adidas Originals T-Shirt      Fashion     Clothing    1499
# 9     FASH004          Puma RS-X Sneakers      Fashion     Footwear    8999
# 10    FASH005   H&M Slim Fit Formal Shirt      Fashion     Clothing    1999
# 11    FASH006  Reebok Training Trackpants      Fashion     Clothing    2299
#
#     stock                                     specifications  \
# 0     150  {'brand': 'Samsung', 'ram': '12GB', 'storage':...
# 1      45  {'brand': 'Apple', 'processor': 'M2 Pro', 'ram...
# 2     200  {'brand': 'Sony', 'type': 'Over-ear', 'connect...
# 3      60  {'brand': 'Dell', 'screen_size': '27 inches', ...
# 4     180  {'brand': 'OnePlus', 'ram': '8GB', 'storage': ...
# 5      35  {'brand': 'Samsung', 'screen_size': '55 inches...
# 6     120  {'brand': 'Levi's', 'material': '98% Cotton, 2...
# 7      85  {'brand': 'Nike', 'type': 'Running Shoes', 'ma...
# 8     200  {'brand': 'Adidas', 'material': '100% Cotton',...
# 9      95  {'brand': 'Puma', 'type': 'Casual Sneakers', '...
# 10    150  {'brand': 'H&M', 'material': 'Cotton blend', '...
# 11    130  {'brand': 'Reebok', 'material': 'Polyester', '...
#
#                                               reviews  \
# 0   [{'user_id': 'U001', 'username': 'TechGuru', '...
# 1   [{'user_id': 'U005', 'username': 'DevPro', 'ra...
# 2   [{'user_id': 'U007', 'username': 'MusicLover',...
# 3   [{'user_id': 'U003', 'username': 'GraphicDesig...
# 4   [{'user_id': 'U010', 'username': 'BudgetBuyer'...
# 5   [{'user_id': 'U008', 'username': 'MovieBuff', ...
# 6   [{'user_id': 'U002', 'username': 'FashionGuy',...
# 7   [{'user_id': 'U004', 'username': 'RunnerLife',...
# 8   [{'user_id': 'U006', 'username': 'CasualStyle'...
# 9   [{'user_id': 'U009', 'username': 'StreetStyle'...
# 10  [{'user_id': 'U011', 'username': 'OfficePro', ...
# 11  [{'user_id': 'U013', 'username': 'FitnessFreak...
#
#                                                  tags  warranty_months  \
# 0                [flagship, 5G, android, photography]               12
# 1                   [laptop, macOS, professional, M2]               12
# 2   [headphones, wireless, noise-cancelling, premium]               24
# 3                    [monitor, 4K, professional, IPS]               36
# 4   [smartphone, mid-range, 5G, android, fast-char...               12
# 5                     [TV, QLED, 4K, smart-tv, 120Hz]               24
# 6                [jeans, denim, casual, mens-fashion]                3
# 7          [shoes, sneakers, running, athletic, nike]                6
# 8               [t-shirt, casual, cotton, sportswear]                3
# 9               [sneakers, casual, retro, streetwear]                6
# 10             [shirt, formal, office-wear, slim-fit]                3
# 11          [trackpants, sportswear, gym, athleisure]                3
#
#                   created_at                updated_at
# 0  2023-12-01 10:00:00+00:00 2024-03-20 14:30:00+00:00
# 1  2023-11-15 09:00:00+00:00 2024-03-18 11:20:00+00:00
# 2  2023-10-20 08:00:00+00:00 2024-03-22 16:45:00+00:00
# 3  2023-11-10 10:30:00+00:00 2024-03-15 09:15:00+00:00
# 4  2024-01-05 11:00:00+00:00 2024-03-25 13:30:00+00:00
# 5  2023-12-15 09:30:00+00:00 2024-03-20 10:00:00+00:00
# 6  2023-10-01 08:00:00+00:00 2024-03-18 14:20:00+00:00
# 7  2023-11-20 10:00:00+00:00 2024-03-22 11:30:00+00:00
# 8  2023-12-10 09:00:00+00:00 2024-03-23 15:10:00+00:00
# 9  2024-01-08 11:30:00+00:00 2024-03-24 12:45:00+00:00
# 10 2023-11-25 10:00:00+00:00 2024-03-19 13:20:00+00:00
# 11 2023-12-05 09:30:00+00:00 2024-03-21 14:50:00+00:00
